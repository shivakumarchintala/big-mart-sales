# %%
import pandas as pd
from sklearn import model_selection, svm, preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor
from xgboost import XGBRegressor
import numpy as np
clf_lr=LinearRegression(n_jobs=1)
clf_dt=DecisionTreeRegressor(max_depth=6)
clf_svml=svm.SVR(kernel='linear')
clf_svmp=svm.SVR(kernel='poly')
clf_xgb=XGBRegressor()
clf_rndmf=RandomForestRegressor()
clf_gbr=GradientBoostingRegressor(learning_rate=0.1, max_depth=6)

# %%
df=pd.read_csv('Bigmart_new.csv')

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
X_pca=df.drop(['Item_Outlet_Sales'],1)
y_pca=df['Item_Outlet_Sales']

# %%
X_pca = StandardScaler().fit_transform(X_pca)

# %%
pca=PCA(n_components=10)
pca_principle=pca.fit_transform(X_pca)

# %%
pca_principle=pd.DataFrame(pca_principle)

# %%
df_final=pd.concat([pca_principle, y_pca],1)

# %%
df_train_full=df_final[:8523]
df_test_full=df_final[8523:]

# %%
X_full=np.array(df_train_full.drop(['Item_Outlet_Sales'], 1))
X_full=preprocessing.scale(X_full)
y_full=np.array(df_train_full['Item_Outlet_Sales'])

# %%
X_train_full, X_test_full, y_train_full, y_test_full=model_selection.train_test_split(X_full, y_full, test_size=0.1)

# %%
clf_lr.fit(X_train_full, y_train_full)
clf_dt.fit(X_train_full, y_train_full)
clf_svml.fit(X_train_full, y_train_full)
clf_svmp.fit(X_train_full, y_train_full)
clf_xgb.fit(X_train_full, y_train_full)
clf_gbr.fit(X_train_full, y_train_full)
clf_rndmf.fit(X_train_full, y_train_full)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
print(clf_lr.score(X_test_full, y_test_full)*100,clf_dt.score(X_test_full, y_test_full)*100,clf_svml.score(X_test_full, y_test_full)*100,clf_svmp.score(X_test_full, y_test_full)*100,clf_xgb.score(X_test_full, y_test_full)*100,clf_gbr.score(X_test_full, y_test_full)*100,clf_rndmf.score(X_test_full, y_test_full)*100 )
# Out:
# 56.80828221097842 58.33951040235388 52.80333515370705 10.264617624695271 61.877885172592805 61.206089184165414 53.52391433892972

# %%
df_test_full=np.array(df_test_full.drop(['Item_Outlet_Sales'], 1))
#implementing xg boost classifier
k=clf_xgb.predict(df_test_full)
k=pd.DataFrame(k)

# %%
k
# Out:
#                 0
# 0     1634.667114
# 1     1762.517700
# 2        2.913724
# 3     2674.332520
# 4     4838.409668
# 5     1681.753296
# 6     2105.712402
# 7     2221.990967
# 8     1530.362427
# 9     3232.764893
# 10    2092.107666
# 11    1405.308472
# 12     390.213226
# 13    1990.318726
# 14     621.739807
# 15    2405.739502
# 16    4175.435547
# 17    3759.378174
# 18    3470.494873
# 19     138.806580
# 20    3038.005859
# 21    2303.767090
# 22    1119.291748
# 23     112.431740
# 24    2965.852295
# 25     654.026001
# 26    1374.562012
# 27    1742.553223
# 28    3886.358643
# 29    2609.616211
# ...           ...
# 5651  3095.347900
# 5652  2103.250488
# 5653  1584.777588
# 5654  2355.151367
# 5655  3134.332520
# 5656  7182.768555
# 5657  3856.197510
# 5658  1887.381348
# 5659  2184.928223
# 5660  3468.994385
# 5661  4023.095947
# 5662  3545.364014
# 5663  1725.496704
# 5664  3975.401367
# 5665  2176.284668
# 5666  3033.672119
# 5667  1244.457520
# 5668   583.939026
# 5669  5554.864258
# 5670  3689.915771
# 5671   956.485046
# 5672  3412.593994
# 5673  2524.540283
# 5674   162.338379
# 5675   965.889587
# 5676  2301.156738
# 5677  3195.440430
# 5678  1241.647095
# 5679  2949.951172
# 5680  1150.655884
#
# [5681 rows x 1 columns]

# %%
k.to_csv('F:\\applied machine learing\\My data set\\project 24\\3_Big smart sales\\sample_shiva.csv')
